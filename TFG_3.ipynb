# %% [markdown]
# DAFO

# %%
from rich.console import Console
from rich.panel import Panel
from rich.layout import Layout

# %% [markdown]
# ANÁLISIS DAFO COMPLETO – NFU

# %%
console = Console()


# FORTALEZAS 
fortalezas = """• Proceso integral y certificado de reciclaje, desde la recogida hasta la valorización.
• Tecnología avanzada en trituración, separación y granulación.
• Compromiso ambiental y contribución directa a la economía circular.
• Diversificación de productos reciclados: caucho, acero y fibras.
• Alianzas estratégicas con talleres, concesionarios y administraciones públicas.
• Certificaciones ISO y cumplimiento normativo riguroso.
• Personal técnico cualificado y especializado en sostenibilidad.

[bold white]Acciones:[/bold white]
• Reforzar el posicionamiento como referente en reciclaje sostenible.
• Comunicar los logros medioambientales mediante marketing verde.
• Mantener la inversión en innovación tecnológica.
• Promover la formación continua del personal técnico.
"""

# DEBILIDADES 
debilidades = """• Dependencia de contratos públicos y licitaciones municipales.
• Costes energéticos y de mantenimiento elevados.
• Escasa notoriedad de marca y visibilidad comercial.
• Limitada capacidad financiera para proyectos de I+D+i.
• Dependencia tecnológica de proveedores externos.
• Espacio industrial y logístico limitado.
• Falta de digitalización completa en gestión de clientes.

[bold white]Acciones:[/bold white]
• Desarrollar una estrategia de marca corporativa sólida.
• Buscar financiación verde y alianzas de inversión sostenible.
• Implementar sistemas de gestión digital (CRM y trazabilidad).
• Optimizar el consumo energético y mantenimiento predictivo.
"""

# OPORTUNIDADES 
oportunidades = """• Expansión del mercado de economía circular y sostenibilidad.
• Subvenciones europeas y nacionales para proyectos verdes.
• Creciente demanda de materiales reciclados en construcción e industria.
• Mayor conciencia ambiental en administraciones y empresas.
• Avances tecnológicos en automatización y control de procesos.
• Colaboraciones con universidades y centros de investigación.
• Oportunidad de certificación ambiental avanzada (ISO 14001, EMAS).

[bold white]Acciones:[/bold white]
• Participar en programas de innovación y proyectos de I+D+i.
• Ampliar la cartera de productos reciclados con valor añadido.
• Certificar bajo estándares internacionales de sostenibilidad.
• Promover alianzas público-privadas para expansión regional.
"""

# AMENAZAS 
amenazas = """• Competencia de otras plantas de reciclaje.
• Cambios normativos que aumenten costes de operación.
• Fluctuación en la demanda de materiales reciclados.
• Riesgos ambientales o reputacionales.
• Incremento de precios en energía y transporte.
• Posibles incidencias de seguridad o cumplimiento ambiental.
• Inestabilidad económica o política que afecte subvenciones.

[bold white]Acciones:[/bold white]
• Vigilar competencia y ajustar precios estratégicamente.
• Asegurar el cumplimiento normativo mediante auditorías.
• Diversificar mercados y clientes industriales.
• Implementar planes de contingencia y gestión de riesgos.
• Crear protocolos de comunicación ante posibles incidentes.
"""

# CONFIGURACIÓN VISUAL 
panel_style = "white on black"

panel_fortalezas = Panel(fortalezas, title="Fortalezas", border_style="green", style=panel_style, padding=(0,1))
panel_debilidades = Panel(debilidades, title="Debilidades", border_style="green", style=panel_style, padding=(0,1))
panel_oportunidades = Panel(oportunidades, title="Oportunidades", border_style="green", style=panel_style, padding=(0,1))
panel_amenazas = Panel(amenazas, title="Amenazas", border_style="green", style=panel_style, padding=(0,1))

layout = Layout()
layout.split(
    Layout(name="upper", size=20),
    Layout(name="lower", size=20)
)
layout["upper"].split_row(
    Layout(panel_fortalezas, name="fortalezas"),
    Layout(panel_debilidades, name="debilidades")
)
layout["lower"].split_row(
    Layout(panel_oportunidades, name="oportunidades"),
    Layout(panel_amenazas, name="amenazas")
)

# ---- SALIDA ----
console.print("\n[bold green]ANÁLISIS DAFO – PLANTA DE RECICLAJE NFU[/bold green]\n")
console.print(layout)
console.print("\n[italic green]Fuente: Elaboración propia (2025), a partir del modelo Canvas y diagnóstico estratégico de la planta NFU.[/italic green]\n")
# Out:
# ANÁLISIS DAFO – PLANTA DE RECICLAJE NFU
# ╭───────────────────── Fortalezas ──────────────────────╮╭───────────────────── Debilidades ──────────────────────╮
# │ • Proceso integral y certificado de reciclaje, desde  ││ • Dependencia de contratos públicos y licitaciones     │
# │ la recogida hasta la valorización.                    ││ municipales.                                           │
# │ • Tecnología avanzada en trituración, separación y    ││ • Costes energéticos y de mantenimiento elevados.      │
# │ granulación.                                          ││ • Escasa notoriedad de marca y visibilidad comercial.  │
# │ • Compromiso ambiental y contribución directa a la    ││ • Limitada capacidad financiera para proyectos de      │
# │ economía circular.                                    ││ I+D+i.                                                 │
# │ • Diversificación de productos reciclados: caucho,    ││ • Dependencia tecnológica de proveedores externos.     │
# ...

# %%
from rich.console import Console
from rich.layout import Layout
from rich.panel import Panel
from rich.text import Text

console = Console()

console.print(Text("Canvas Aplicado – Planta de Reciclaje de NFU", style="bold white on green", justify="center"))
console.print("")

socios = """• Proveedores de NFU (talleres, concesionarios)
• Transporte y logística
• Fabricantes de maquinaria
• Organismos ambientales
• Fondos verdes y universidades"""

actividades = """• Recogida y transporte de NFU
• Triturado y separación de materiales
• Control de calidad y certificación
• I+D en productos sostenibles
• Comercialización y relaciones institucionales"""

recursos = """• Planta industrial moderna
• Maquinaria especializada
• Personal técnico cualificado
• Licencias y certificaciones
• Capital e infraestructura digital"""

propuesta = """• Industrias: caucho reciclado de calidad
• Talleres: gestión segura y trazable
• Administraciones: valorización integral
• Constructoras: materiales certificados sostenibles"""

segmentos = """• Industrias del caucho
• Talleres mecánicos
• Administraciones públicas
• Constructoras
• Empresas ecológicas"""

relacion = """• Contratos a largo plazo
• Atención personalizada
• Reportes ambientales
• Asesoría técnica y acompañamiento"""

canales = """• Ventas directas y ferias
• Convenios locales y digitales
• Licitaciones públicas
• Presentaciones técnicas y visitas"""

costes = """• Inversión en maquinaria e infraestructura
• Costes operativos y mantenimiento
• Sueldos y formación
• Administración y certificaciones
• Marketing e innovación"""

ingresos = """• Venta de caucho y acero reciclado
• Contratos de gestión NFU
• Servicios logísticos y de valorización
• Subvenciones y programas verdes
• Consultoría y créditos de carbono"""

panel_style = "white on black"
def P(text, title):
    return Panel(text, title=title, border_style="green", style=panel_style, padding=(0,1))

layout = Layout()

# filas fijas compactas (ajusta size si necesitas panels más/menos altos)
layout.split_column(
    Layout(name="fila1", size=10),
    Layout(name="fila2", size=10),
    Layout(name="fila3", size=10),
)

# cada fila se divide en 3 columnas compactas (sin tamaños fijos; usarán espacio disponible)
layout["fila1"].split_row(
    Layout(P(socios, "Socios Clave")),
    Layout(P(propuesta, "Propuesta de Valor")),
    Layout(P(segmentos, "Segmentos de Clientes")),
)

layout["fila2"].split_row(
    Layout(P(actividades, "Actividades Clave")),
    Layout(P(relacion, "Relación con Clientes")),
    Layout(P(canales, "Canales")),
)

layout["fila3"].split_row(
    Layout(P(recursos, "Recursos Clave")),
    Layout(P(costes, "Estructura de Costes")),
    Layout(P(ingresos, "Fuentes de Ingresos")),
)

console.print(layout)
# Out:
# Canvas Aplicado – Planta de Reciclaje de NFU
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────── Socios Clave ───────────╮╭──────── Propuesta de Valor ────────╮╭─────── Segmentos de Clientes ───────╮
# │ • Proveedores de NFU (talleres,    ││ • Industrias: caucho reciclado de  ││ • Industrias del caucho             │
# │ concesionarios)                    ││ calidad                            ││ • Talleres mecánicos                │
# │ • Transporte y logística           ││ • Talleres: gestión segura y       ││ • Administraciones públicas         │
# │ • Fabricantes de maquinaria        ││ trazable                           ││ • Constructoras                     │
# │ • Organismos ambientales           ││ • Administraciones: valorización   ││ • Empresas ecológicas               │
# ...

# %% [markdown]
# Mapa de Empatía – Planta de Reciclaje

# %%
from rich.console import Console
from rich.layout import Layout
from rich.panel import Panel
from rich.text import Text

# %%
console = Console()

# Título del mapa
console.print(Text("Mapa de Empatía – Planta de Reciclaje de NFU", style="bold white on green", justify="center"))

# Contenidos de cada cuadrante
piensa = """• Busca optimizar operaciones y reducir costes.
• Desea cumplir normativas ambientales.
• Se preocupa por la reputación sostenible.
• Aspira a la economía circular, teme costes iniciales.
• Siente presión por una correcta disposición de los NFU."""

siente = """• Frustración por trámites y logística compleja.
• Dificultad para hallar proveedores confiables.
• Temor a sanciones o incumplimientos.
• Falta de información técnica clara.
• Deseo de mejorar su impacto ambiental."""

dice = """• Expresa interés por proveedores sostenibles.
• Solicita trazabilidad y calidad certificada.
• Compara precios y servicios de gestión.
• Participa en reuniones y ferias del sector."""

hace = """• Implementa mejoras operativas.
• Busca alianzas con plantas certificadas.
• Realiza auditorías internas de sostenibilidad.
• Promueve la imagen verde de su empresa."""

pains = """• Procesos administrativos lentos.
• Costes altos de gestión y transporte.
• Falta de soluciones integrales y certificadas.
• Riesgo de sanciones normativas."""

gains = """• Ahorro en costes y cumplimiento legal.
• Acceso a materiales reciclados de calidad.
• Reputación corporativa positiva.
• Contribución real a la economía circular."""

# Función que construye cada panel del mapa
def P(text, title, color="green"):
    return Panel(
        text.strip(),
        title=title,
        border_style=color,
        style="white on black",
        padding=(0, 1),
        expand=True
    )

# Sección principal del layout
layout = Layout()

# Distribución general: 3 filas (superior, intermedia e inferior)
layout.split_column(
    Layout(name="fila_superior", ratio=1),
    Layout(name="fila_inferior", ratio=1),
    Layout(name="fila_bottom", ratio=1)
)

# Fila superior: qué dice, quién es el cliente y qué piensa
layout["fila_superior"].split_row(
    Layout(P(dice, "DICE", "yellow"), ratio=1),
    Layout(P("CLIENTE\nEmpresa que gestiona y recicla neumáticos.\nBusca sostenibilidad, cumplimiento y rentabilidad.", "Perfil del Cliente", "bright_green"), ratio=1),
    Layout(P(piensa, "PIENSA", "cyan"), ratio=1)
)

# Fila intermedia: qué hace y qué siente
layout["fila_inferior"].split_row(
    Layout(P(hace, "HACE", "bright_yellow"), ratio=1),
    Layout(P(siente, "SIENTE", "bright_cyan"), ratio=1)
)

# Fila inferior: esfuerzos (pains) y beneficios (gains)
layout["fila_bottom"].split_row(
    Layout(P(pains, "ESFUERZOS / PAINS", "red"), ratio=1),
    Layout(P(gains, "BENEFICIOS / GAINS", "green"), ratio=1)
)

# Ajuste de proporciones para eliminar espacios entre paneles
for section in layout.children:
    section.size = None
    section.ratio = 1
    section.minimum_size = 0
    if hasattr(section, "children"):
        for sub in section.children:
            sub.minimum_size = 0
            sub.ratio = 1

# Muestra el mapa completo en la consola
console.print(layout)
# Out:
# Mapa de Empatía – Planta de Reciclaje de NFU
# ╭─────────────── DICE ───────────────╮╭──────── Perfil del Cliente ────────╮╭────────────── PIENSA ───────────────╮
# │ • Expresa interés por proveedores  ││ CLIENTE                            ││ • Busca optimizar operaciones y     │
# │ sostenibles.                       ││ Empresa que gestiona y recicla     ││ reducir costes.                     │
# │ • Solicita trazabilidad y calidad  ││ neumáticos.                        ││ • Desea cumplir normativas          │
# │ certificada.                       ││ Busca sostenibilidad, cumplimiento ││ ambientales.                        │
# │ • Compara precios y servicios de   ││ y rentabilidad.                    ││ • Se preocupa por la reputación     │
# │ gestión.                           ││                                    ││ sostenible.                         │
# │ • Participa en reuniones y ferias  ││                                    ││ • Aspira a la economía circular,    │
# ...

# %%
# !pip install reportlab
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# CURVA DE VALOR - PLANTA NFU vs COMPETENCIA
# Versión avanzada con:
# - Escala 0-10
# - Anotaciones en el gráfico
# - Exportación automática a PDF profesional

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, Table, TableStyle
from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet

# %%
# Datos base

data = {
    "Factor de Valor": [
        "Calidad del material reciclado",
        "Precio",
        "Cumplimiento normativo",
        "Rapidez en la entrega",
        "Servicio y soporte técnico",
        "Sostenibilidad y responsabilidad ambiental"
    ],
    "Nivel Actual de la Competencia": [
        "Medio",
        "Medio",
        "Medio",
        "Medio",
        "Medio",
        "Bajo"
    ],
    "Nivel Planta NFU": [
        "Alto",
        "Medio-Alto",
        "Alto",
        "Medio",
        "Alto",
        "Muy Alto"
    ],
    "Análisis e Interpretación": [
        "NFU invierte en tecnología avanzada que garantiza caucho reciclado de alta pureza, apto para industrias exigentes.",
        "Precio algo superior al informal, pero justificado por calidad certificada, trazabilidad y garantía ambiental.",
        "Opera bajo normas ISO y regulaciones ambientales; genera confianza en clientes institucionales.",
        "Tiempos de entrega competitivos, aunque la prioridad está en la calidad y sostenibilidad.",
        "Ofrece soporte técnico postventa y asesoramiento personalizado, fortaleciendo relaciones a largo plazo.",
        "Integra prácticas de economía circular, reducción de huella de carbono y certificaciones ambientales. Atributo más distintivo."
    ]
}

df = pd.DataFrame(data)


# Mapeo a escala 0-10

mapping = {
    "Bajo": 2,
    "Medio": 5,
    "Medio-Alto": 7,
    "Alto": 8,
    "Muy Alto": 10
}

df["Competencia (0-10)"] = df["Nivel Actual de la Competencia"].map(mapping)
df["NFU (0-10)"] = df["Nivel Planta NFU"].map(mapping)

# Gráfico Radar

labels = df["Factor de Valor"].tolist()
vals_comp = df["Competencia (0-10)"].tolist()
vals_nfu = df["NFU (0-10)"].tolist()

labels_closed = labels + [labels[0]]
vals_comp_closed = vals_comp + [vals_comp[0]]
vals_nfu_closed = vals_nfu + [vals_nfu[0]]

N = len(labels)
angles = [n / float(N) * 2 * math.pi for n in range(N)]
angles += [angles[0]]

plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)
plt.xticks(angles[:-1], labels, fontsize=9)
ax.set_rlabel_position(30)
plt.yticks([2,4,6,8,10], ["2","4","6","8","10"], fontsize=8)
plt.ylim(0,10)

# Competencia
ax.plot(angles, vals_comp_closed, linewidth=1, linestyle='solid', label="Competencia")
ax.fill(angles, vals_comp_closed, alpha=0.1)

# NFU
ax.plot(angles, vals_nfu_closed, linewidth=2, linestyle='solid', label="Planta NFU")
ax.fill(angles, vals_nfu_closed, alpha=0.15)

plt.title("Curva de Valor: Planta NFU vs Competencia (escala 0-10)", y=1.1, fontsize=13)
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.1))

# Anotaciones automáticas
max_idx = np.argmax(vals_nfu)
min_idx = np.argmin(vals_nfu)
ax.annotate("Mayor ventaja:\n" + labels[max_idx],
            xy=(angles[max_idx], vals_nfu[max_idx]),
            xytext=(angles[max_idx], vals_nfu[max_idx]+1),
            arrowprops=dict(facecolor='green', shrink=0.05),
            fontsize=8, color='green')
ax.annotate("Área a mejorar:\n" + labels[min_idx],
            xy=(angles[min_idx], vals_nfu[min_idx]),
            xytext=(angles[min_idx], vals_nfu[min_idx]-3),
            arrowprops=dict(facecolor='red', shrink=0.05),
            fontsize=8, color='red')

radar_path = "/mnt/data/curva_valor_nfu_radar_avanzada.png"
plt.savefig(radar_path, bbox_inches='tight', dpi=150)
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 101
#      94 ax.annotate("Área a mejorar:\n" + labels[min_idx],
#      95             xy=(angles[min_idx], vals_nfu[min_idx]),
#      96             xytext=(angles[min_idx], vals_nfu[min_idx]-3),
#      97             arrowprops=dict(facecolor='red', shrink=0.05),
#      98             fontsize=8, color='red')
#     100 radar_path = "/mnt/data/curva_valor_nfu_radar_avanzada.png"
# --> 101 plt.savefig(radar_path, bbox_inches='tight', dpi=150)
#     102 plt.close()
#     104 # -------------------------
#     105 # Exportar a PDF
#     106 # -------------------------
#
# File c:\Users\Asus Vivobook\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
# ...

# %% [markdown]
# Customer Journey Map

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Etapas del viaje del cliente
etapas = ["Conciencia", "Consideración", "Compra / Contrato", "Recepción / Servicio", "Postventa"]
x = np.arange(len(etapas))

# Niveles de experiencia (escala 1-10)
nfu = [8, 8, 9, 9, 8]           # Planta NFU
competencia = [5, 6, 6, 7, 5]   # Competencia

# Crear la figura
plt.figure(figsize=(10, 6))
plt.plot(x, competencia, 'o--', color="#999999", linewidth=2, markersize=8, label="Competencia")
plt.plot(x, nfu, 'o-', color="#008080", linewidth=3, markersize=8, label="Planta NFU")

# Fondo y estilo
plt.fill_between(x, competencia, nfu, where=(np.array(nfu) > np.array(competencia)),
                 color="#b2d8d8", alpha=0.3)

# Etiquetas y títulos
plt.xticks(x, etapas, fontsize=10)
plt.yticks(np.arange(0, 11, 1))
plt.ylim(0, 10)
plt.title("Mapa de Viaje del Cliente – Comparativa NFU vs Competencia", fontsize=13, fontweight='bold', color="#004c4c")
plt.xlabel("Etapas del viaje del cliente", fontsize=10)
plt.ylabel("Nivel de experiencia percibida (1–10)", fontsize=10)

# Anotaciones de resumen estratégico
resumen = [
    "Dar visibilidad clara de servicios\nEducación ambiental y sostenibilidad",
    "Transparencia en precios y certificaciones",
    "Simplificar contratos\nAsesoría técnica",
    "Puntualidad y calidad en entregas",
    "Soporte técnico y fidelización"
]

for i, text in enumerate(resumen):
    plt.text(i, nfu[i]+0.5, text, ha='center', va='bottom', fontsize=8, color="#004c4c", wrap=True)


)
plt.text(5.2, 4.5, texto, fontsize=8.5, color="#333333", va="top", wrap=True, bbox=dict(facecolor='white', edgecolor='#cccccc', boxstyle='round,pad=0.5'))

# Leyenda y estilo final
plt.legend(loc="lower right", fontsize=9)
plt.grid(alpha=0.2)
plt.tight_layout()

# Guardar imagen
output_path = "/mnt/data/Mapa_Viaje_Cliente_NFU_vs_Competencia.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.show()

print(f"Imagen generada: {output_path}")
# Out:
#   Cell In[1], line 39
#     )
#     ^
# SyntaxError: unmatched ')'

# %% [markdown]
# # 7. ANÁLISIS DE RIESGOS Y MEDIDAS DE MITIGACIÓN - PYTHON

# %% [markdown]
# # 4.3. Mapa de Viaje del Cliente (Customer Journey Map)
# # Planta de Reciclaje de NFU

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
etapas = [
    "Atracción",
    "Captación",
    "Prestación del servicio",
    "Mantenimiento / Fidelización"
]

emociones = [3, 4, 5, 4]  # Escala de 1 a 5

actividades = [
    "Búsqueda de soluciones sostenibles\nConsulta web o redes profesionales",
    "Solicitud de asesoría técnica\nCotización y trazabilidad del servicio",
    "Recolección y reciclaje certificado\nEntrega de informes y certificados ambientales",
    "Seguimiento postventa y fidelización\nProgramas verdes y atención continua"
]

touchpoints = [
    "Web corporativa, ferias y redes sociales",
    "Correo electrónico, reuniones técnicas",
    "Transporte, app de trazabilidad, certificados",
    "Portal cliente, soporte técnico, beneficios verdes"
]

puntos_dolor = [
    "Desconfianza inicial en proveedores ambientales",
    "Tiempos de respuesta o burocracia en cotizaciones",
    "Retrasos logísticos o problemas de trazabilidad digital",
    "Falta de actualización o incentivos de fidelización"
]

oportunidades = [
    "Reforzar comunicación verde y credibilidad técnica",
    "Optimizar atención comercial y digitalizar cotizaciones",
    "Automatizar trazabilidad y mejorar coordinación logística",
    "Implementar programas de fidelización y reporting proactivo"
]

colores = ['orange', 'yellowgreen', 'limegreen', 'green']


# Crear el gráfico

plt.figure(figsize=(15, 8))  # más ancho
x = np.arange(len(etapas))

# Línea emocional del cliente
plt.plot(x, emociones, marker='o', linewidth=3, color='steelblue', alpha=0.85)
plt.fill_between(x, emociones, [min(emociones)]*len(emociones), color='skyblue', alpha=0.25)


# Texto dentro del área del gráfico

for i in range(len(etapas)):
    plt.scatter(x[i], emociones[i], color=colores[i], s=400, edgecolor='black', zorder=5)

    # Actividades (arriba del punto, centrado)
    plt.text(x[i], emociones[i] + 0.35, actividades[i],
             fontsize=9, ha='center', va='bottom', wrap=True, fontweight='bold')

    # Touchpoints (debajo del punto)
    plt.text(x[i], emociones[i] - 0.55, f"Touchpoints:\n{touchpoints[i]}",
             fontsize=8, ha='center', va='top', color='dimgray', wrap=True)


# Puntos de dolor y oportunidades (más dentro del área)

for i in range(len(etapas)):
    plt.text(x[i], 1.1, f"Puntos de dolor:\n{puntos_dolor[i]}",
             fontsize=8, ha='center', color='firebrick', wrap=True)
    plt.text(x[i], 0.3, f"Oportunidades:\n{oportunidades[i]}",
             fontsize=8, ha='center', color='darkgreen', wrap=True)

# Personalización estética

plt.xticks(x, etapas, fontsize=10, weight='bold')
plt.ylim(0, 6.2)
plt.xlim(-0.6, len(etapas) - 0.4)  # Deja más espacio al inicio y al final
plt.ylabel("Nivel de satisfacción / emoción", fontsize=10)
plt.title("Mapa de Viaje del Cliente - Planta de Reciclaje de NFU", fontsize=15, weight='bold', pad=20)
plt.grid(alpha=0.3, linestyle='--')

# Margen adicional para que el texto entre completamente
plt.subplots_adjust(left=0.07, right=0.93, top=0.9, bottom=0.1)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus Vivobook\AppData\Local\Temp\ipykernel_22448\4229081631.py:102: UserWarning: Glyph 128997 (\N{LARGE RED SQUARE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Asus Vivobook\AppData\Local\Temp\ipykernel_22448\4229081631.py:102: UserWarning: Glyph 129001 (\N{LARGE GREEN SQUARE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Asus Vivobook\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128997 (\N{LARGE RED SQUARE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Asus Vivobook\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129001 (\N{LARGE GREEN SQUARE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Tipo de riesgo": [
        "Operativo",
        "Financiero",
        "Legal",
        "Ambiental",
        "Social"
    ],
    "Ejemplo": [
        "Avería crítica en maquinaria principal",
        "Aumento de costes energéticos",
        "Cambios en normativa ambiental",
        "Vertido accidental o emisión no controlada",
        "Conflicto con comunidad local"
    ],
    "Probabilidad": [
        "Media",
        "Alta",
        "Media",
        "Baja",
        "Baja"
    ],
    "Impacto": [
        "Alta",
        "Alta",
        "Media",
        "Alta",
        "Media"
    ],
    "Nivel de riesgo": [
        "Alto",
        "Muy Alto",
        "Medio",
        "Alto",
        "Bajo"
    ]
}

matriz_riesgos = pd.DataFrame(data)

print("MATRIZ DE RIESGOS - PLANTA DE RECICLAJE DE NFU\n")
print(matriz_riesgos.to_string(index=False))


# 7.2 VALORACIÓN NUMÉRICA


map_prob = {"Baja": 1, "Media": 2, "Alta": 3}
map_imp = {"Media": 2, "Alta": 3}

matriz_riesgos["Probabilidad_num"] = matriz_riesgos["Probabilidad"].map(map_prob)
matriz_riesgos["Impacto_num"] = matriz_riesgos["Impacto"].map(map_imp)
matriz_riesgos["Índice de Riesgo"] = matriz_riesgos["Probabilidad_num"] * matriz_riesgos["Impacto_num"]


# 7.3 VISUALIZACIÓN - MAPA DE CALOR


plt.figure(figsize=(7, 5))
sns.heatmap(
    matriz_riesgos.pivot_table(index="Tipo de riesgo", values="Índice de Riesgo"),
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    linecolor="gray",
    cbar_kws={'label': 'Nivel de Riesgo (1-9)'}
)

plt.title("Mapa de Calor - Matriz de Riesgos", fontsize=13, weight='bold', pad=10)
plt.xlabel("")
plt.ylabel("Tipo de Riesgo")
plt.tight_layout()
plt.show()
# Out:
# MATRIZ DE RIESGOS - PLANTA DE RECICLAJE DE NFU
#
# Tipo de riesgo                                    Ejemplo Probabilidad Impacto Nivel de riesgo
#      Operativo     Avería crítica en maquinaria principal        Media    Alta            Alto
#     Financiero              Aumento de costes energéticos         Alta    Alta        Muy Alto
#          Legal             Cambios en normativa ambiental        Media   Media           Medio
#      Ambiental Vertido accidental o emisión no controlada         Baja    Alta            Alto
#         Social              Conflicto con comunidad local         Baja   Media            Bajo
